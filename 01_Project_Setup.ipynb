# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
print(pd.__version__)
# Out:
# 2.2.3

# %%
import pandas as pd

race_results = pd.read_csv("../Data/raw/kaggle/f1_2024_race_results.csv")

race_results.head()
# Out:
#    race_id           race_name                        circuit    city  \
# 0        1  Bahrain Grand Prix  Bahrain International Circuit  Sakhir
# 1        1  Bahrain Grand Prix  Bahrain International Circuit  Sakhir
# 2        1  Bahrain Grand Prix  Bahrain International Circuit  Sakhir
# 3        1  Bahrain Grand Prix  Bahrain International Circuit  Sakhir
# 4        1  Bahrain Grand Prix  Bahrain International Circuit  Sakhir
#
#    country  circuit_length_km  total_laps  position     driver_name  \
# 0  Bahrain              5.412          57         1  Max Verstappen
# 1  Bahrain              5.412          57         2  Lewis Hamilton
# 2  Bahrain              5.412          57         3    Carlos Sainz
# 3  Bahrain              5.412          57         4    Sergio Perez
# 4  Bahrain              5.412          57         5  George Russell
#
#               team nationality  car_number    race_time  points fastest_lap  \
# ...

# %%
race_results.info()
race_results.shape
race_results.columns
race_results.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   race_id            480 non-null    int64
#  1   race_name          480 non-null    object
#  2   circuit            480 non-null    object
#  3   city               480 non-null    object
#  4   country            480 non-null    object
#  5   circuit_length_km  480 non-null    float64
#  6   total_laps         480 non-null    int64
#  7   position           480 non-null    int64
#  8   driver_name        480 non-null    object
#  9   team               480 non-null    object
#  10  nationality        480 non-null    object
#  11  car_number         480 non-null    int64
#  12  race_time          480 non-null    object
#  13  points             480 non-null    int64
#  14  fastest_lap        480 non-null    object
#  15  pole_position      480 non-null    object
# ...

# %%
race_results.isnull().sum()
# Out:
# race_id              0
# race_name            0
# circuit              0
# city                 0
# country              0
# circuit_length_km    0
# total_laps           0
# position             0
# driver_name          0
# team                 0
# nationality          0
# car_number           0
# race_time            0
# points               0
# fastest_lap          0
# pole_position        0
# dtype: int64

# %%
race_results.duplicated().sum()
# Out:
# np.int64(0)

# %%
race_results.dtypes
# Out:
# race_id                int64
# race_name             object
# circuit               object
# city                  object
# country               object
# circuit_length_km    float64
# total_laps             int64
# position               int64
# driver_name           object
# team                  object
# nationality           object
# car_number             int64
# race_time             object
# points                 int64
# fastest_lap           object
# pole_position         object
# dtype: object

# %%
race_results.to_csv("../Data/processed/race_results_clean.csv", index=False)

print("Clean dataset saved successfully!")
# Out:
# Clean dataset saved successfully!
